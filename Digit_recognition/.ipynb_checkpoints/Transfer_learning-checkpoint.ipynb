# %%
import numpy as np
import pandas as pd
import seaborn as sns
import tensorflow as tf

from tensorflow.keras.layers import Input, Dense, Flatten, Conv2D, MaxPooling2D, Dropout
from tensorflow import keras

from sklearn.model_selection import train_test_split

# %%
# Load training and testing dataframes
df_train = pd.read_csv("data/train.csv")
df_test = pd.read_csv("data/test.csv")

# %%
# Create training and testing arrays
training = np.array(df_train, dtype = 'float32')
testing = np.array(df_test, dtype='float32')

# %%
# check if the target classes are balanced
plt.figure(figsize=(10,6))
sns.countplot(x='label', data=df_train)
# Out:
# <AxesSubplot:xlabel='label', ylabel='count'>

# %%
# Visualize the training data
W = 5
H = 5
fig, axes = plt.subplots(W, H, figsize = (10,10))
axes = axes.reshape(-1) # flaten the matrix into array

# Show a random number from testing images 
for i in np.arange(0, W * H): 
    # Select a random number
    index = np.random.randint(0, len(df_train))
    
    # Read and display an image with the selected index    
    axes[i].imshow(training[index,1:].reshape((28,28)))
    axes[i].set_title(training[index,0].astype(int), fontsize = 10) # the label
    axes[i].axis('off')

plt.show()

# %%
# visualize the test data
W = 5
H = 5
fig, axes = plt.subplots(W, H, figsize = (10,10))
axes = axes.reshape(-1) # flaten the matrix into array

# Show a random number from testing images 
for i in np.arange(0, W * H): 
    # Select a random number
    index = np.random.randint(0, len(testing))
    
    # Read and display an image with the selected index    
    axes[i].imshow(testing[index,:].reshape((28,28)))
    axes[i].axis('off')

plt.show()

# %%
X_train_data = training[:, 1:]
# y = training[:, 0] # For loss='sparse_categorical_crossentropy'
y_train_data = keras.utils.to_categorical(training[:, 0], 10)

test_data = testing

X = X / 255
test_data = test_data / 255

# %%
X_train, X_test, y_train, y_test = train_test_split(X_train_data, y_train_data, test_size=0.2)

# %%
X_train = X_train.reshape(X_train.shape[0], 28, 28, 1)
X_test = X_test.reshape(X_test.shape[0], 28, 28, 1)
test_data = test_data.reshape(test_data.shape[0], 28, 28, 1)

X_train.shape, y_train.shape, X_test.shape, y_test.shape, test_data.shape
# Out:
# ((33600, 28, 28, 1),
#  (33600, 10),
#  (8400, 28, 28, 1),
#  (8400, 10),
#  (28000, 28, 28, 1))

# %%
# Setup input shape to the model
INPUT_SHAPE = [None, 28, 28, 1] # batch, height, width, colour channels

# Setup output shape of the model
OUTPUT_SHAPE = 10 # number of unique labels

# Setup model URL from TensorFlow Hub
MODEL_URL = "https://tfhub.dev/google/imagenet/resnet_v2_152/classification/5"

# %%
model.compile(optimizer=keras.optimizers.Adam(learning_rate=0.001),
              loss='categorical_crossentropy',
              metrics='accuracy')

# %%
tf.random.set_seed(42)

a = model.fit(X_train, 
           y_train, 
           batch_size=32, 
           epochs=15, 
           validation_data=(X_test, y_test),
          )
a
# Out:
# Epoch 1/15
# 1050/1050 [==============================] - 16s 15ms/step - loss: 0.0350 - accuracy: 0.9885 - val_loss: 0.0424 - val_accuracy: 0.9880
# Epoch 2/15
# 1050/1050 [==============================] - 15s 15ms/step - loss: 0.0319 - accuracy: 0.9894 - val_loss: 0.0377 - val_accuracy: 0.9880
# Epoch 3/15
# 1050/1050 [==============================] - 16s 15ms/step - loss: 0.0258 - accuracy: 0.9917 - val_loss: 0.0372 - val_accuracy: 0.9899
# Epoch 4/15
# 1050/1050 [==============================] - 15s 15ms/step - loss: 0.0231 - accuracy: 0.9928 - val_loss: 0.0371 - val_accuracy: 0.9889
# Epoch 5/15
# 1050/1050 [==============================] - 16s 15ms/step - loss: 0.0186 - accuracy: 0.9944 - val_loss: 0.0412 - val_accuracy: 0.9883
# Epoch 6/15
# 1050/1050 [==============================] - 16s 15ms/step - loss: 0.0263 - accuracy: 0.9918 - val_loss: 0.0454 - val_accuracy: 0.9889
# Epoch 7/15
# 1050/1050 [==============================] - 16s 15ms/step - loss: 0.0240 - accuracy: 0.9921 - val_loss: 0.0373 - val_accuracy: 0.9890
# Epoch 8/15
# 1050/1050 [==============================] - 16s 15ms/step - loss: 0.0191 - accuracy: 0.9934 - val_loss: 0.0371 - val_accuracy: 0.9898
# Epoch 9/15
# 1050/1050 [==============================] - 16s 15ms/step - loss: 0.0168 - accuracy: 0.9950 - val_loss: 0.0412 - val_accuracy: 0.9902
# Epoch 10/15
# 1050/1050 [==============================] - 16s 15ms/step - loss: 0.0180 - accuracy: 0.9943 - val_loss: 0.0408 - val_accuracy: 0.9895
# Epoch 11/15
# 1050/1050 [==============================] - 16s 15ms/step - loss: 0.0164 - accuracy: 0.9949 - val_loss: 0.0422 - val_accuracy: 0.9913
# Epoch 12/15
# 1050/1050 [==============================] - 16s 15ms/step - loss: 0.0149 - accuracy: 0.9950 - val_loss: 0.0503 - val_accuracy: 0.9888
# Epoch 13/15
# 1050/1050 [==============================] - 16s 15ms/step - loss: 0.0141 - accuracy: 0.9951 - val_loss: 0.0463 - val_accuracy: 0.9890
# Epoch 14/15
# 1050/1050 [==============================] - 16s 15ms/step - loss: 0.0142 - accuracy: 0.9954 - val_loss: 0.0465 - val_accuracy: 0.9907
# Epoch 15/15
# 1050/1050 [==============================] - 16s 15ms/step - loss: 0.0129 - accuracy: 0.9956 - val_loss: 0.0466 - val_accuracy: 0.9906

# %%
predictions = pd.read_csv("data/sample_submission.csv")
predictions.drop("Label", axis=1, inplace=True)
predictions["Label"] = model.predict(test_data).argmax(axis=1)

# %%
predictions.to_csv("data/my_second_preds.csv", index=False)

# %%
0.9869
